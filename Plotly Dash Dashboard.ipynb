# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\ronaknandanwar\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: colorama in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
#      ---------------------------------------- 75.3/75.3 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Flask>=1.0.4 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash==1.19.0) (1.13)
# Requirement already satisfied: plotly in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash==1.19.0) (5.9.0)
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#      -------------------------------------- 188.2/188.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.4)
# Requirement already satisfied: brotli in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash_renderer, dash-table
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84007 sha256=058af2364368a923bc1be3a54a7e06d591788c0ba88f49a3e4f662ceaaf11923
#   Stored in directory: c:\users\ronaknandanwar\appdata\local\pip\cache\wheels\d3\a4\51\d5de70e3fbed7165091a1972b5d60522f078d8f3b0938c6bc6
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3526989 sha256=c2725293d7c53e4d5b7d32bac94597b438a7f727ba4b0008e1d647c73d26bc1e
#   Stored in directory: c:\users\ronaknandanwar\appdata\local\pip\cache\wheels\17\6f\34\e5d7fe1c7189531b3c6c90266df517f73210b9ccf6aabd9c53
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427829 sha256=6be38f1966613354dcd93483216277c851cb04184b3947dd6be7f0303d60f068
#   Stored in directory: c:\users\ronaknandanwar\appdata\local\pip\cache\wheels\89\69\97\d277cdcfc9018c0c50a181a3572895c323f324ce30616e988e
#   Building wheel for dash_renderer (setup.py): started
#   Building wheel for dash_renderer (setup.py): finished with status 'done'
#   Created wheel for dash_renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014846 sha256=ff8ba0edda952940380de27f53461316007e5965ab2097ce1886bf5124ae9a51
#   Stored in directory: c:\users\ronaknandanwar\appdata\local\pip\cache\wheels\9d\82\83\b39e9f2d6941ed7f500c579bb8c2e20c317638d84be58c63f2
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839849 sha256=5ca8a61c1c74ce0b975f94330ce7915c3bc3c8cfd2900a6f4f3f11c5cd3b925d
#   Stored in directory: c:\users\ronaknandanwar\appdata\local\pip\cache\wheels\b6\7d\d0\1058eb26f3a2df4211086fb79bcb232357139aa1fc3abc15a2
# Successfully built dash dash-core-components dash-html-components dash_renderer dash-table
# Installing collected packages: dash-table, dash_renderer, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.7.1
#     Uninstalling dash-2.7.1:
#       Successfully uninstalled dash-2.7.1
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2 dash_renderer-1.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dtale 2.10.0 requires dash>=2.0.0; python_version > "3.6", but you have dash 1.19.0 which is incompatible.
# dash-bootstrap-components 1.3.0 requires dash>=2.0.0, but you have dash 1.19.0 which is incompatible.
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: ipykernel in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (6.15.2)
# Requirement already satisfied: ipython in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (7.31.1)
# Requirement already satisfied: requests in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (2.28.1)
# Requirement already satisfied: flask in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: dash in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: nest-asyncio in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter_dash) (1.5.5)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: plotly in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.9.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: psutil in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: packaging in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (21.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (23.2.0)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: backcall in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pygments in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: colorama in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.5)
# Requirement already satisfied: decorator in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from ipython->jupyter_dash) (63.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.11)
# Requirement already satisfied: six>=1.7.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (4.11.1)
# Requirement already satisfied: entrypoints in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: wcwidth in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from packaging->ipykernel->jupyter_dash) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (302)
# Installing collected packages: retrying, ansi2html, jupyter_dash
# Successfully installed ansi2html-1.8.0 jupyter_dash-0.4.2 retrying-1.3.4
# Requirement already satisfied: plotly in c:\users\ronaknandanwar\anaconda3\lib\site-packages (5.9.0)
# Collecting plotly
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      ---------------------------------------- 15.2/15.2 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ronaknandanwar\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
# Successfully installed plotly-5.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dtale 2.10.0 requires dash>=2.0.0; python_version > "3.6", but you have dash 1.19.0 which is incompatible.
# dash-bootstrap-components 1.3.0 requires dash>=2.0.0, but you have dash 1.19.0 which is incompatible.

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
JupyterDash.infer_jupyter_proxy_config()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23860\326626489.py in <module>
# ----> 1 JupyterDash.infer_jupyter_proxy_config()
#
# ~\anaconda3\lib\site-packages\jupyter_dash\jupyter_app.py in infer_jupyter_proxy_config(cls)
#      80         else:
#      81             # Assume classic notebook or JupyterLab
# ---> 82             _request_jupyter_config()
#      83
#      84     def __init__(self, name=None, server_url=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\jupyter_dash\comms.py in _request_jupyter_config(timeout)
#      70         if (time.time() - t0) > timeout:
#      71             # give up
# ---> 72             raise EnvironmentError(
#      73                 "Unable to communicate with the jupyter_dash notebook or JupyterLab \n"
#      74                 "extension required to infer Jupyter configuration."
#
# OSError: Unable to communicate with the jupyter_dash notebook or JupyterLab
# extension required to infer Jupyter configuration.
